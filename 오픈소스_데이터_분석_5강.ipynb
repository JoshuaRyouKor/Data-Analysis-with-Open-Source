# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaRyouKor/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성

## CSV 형식 저장

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트

import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장

## DataFrame을 이용한 저장

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame([data])

## DataFrame 인덱스 출력

## DataFrame 컬럼 출력

## DataFrame 행 출력

## DataFrame 값 출력

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1=pd.DataFrame.from_dict(data)
df2=pd.read_csv('students.csv')
df3=pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df2.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv('students_score.csv')
df.to_json('studnets_score.json')

## HTML 형식으로 저장
html_table = df.to_html()
with open('studnets_scores.html','w') as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
response.json()
# Out:
# {'response': {'body': {'totalCount': 40,
#    'items': [{'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '143',
#      'so2Value': '0.003',
#      'coValue': '0.7',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '70',
#      'khaiGrade': '3',
#      'pm25Value': '53',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
#      'o3Flag': None,
#      'pm25Grade': '3',
#      'so2Flag': None,
#      'dataTime': '2026-01-17 13:00',
#      'coGrade': '1',
#      'no2Value': '0.024',
#      'stationName': '중구',
#      'pm10Grade': '2',
#      'o3Value': '0.027'},
#     {'so2Grade': '1',
#      'coFlag': None,
#      'khaiValue': '85',
#      'so2Value': '0.003',
#      'coValue': '0.8',
#      'pm25Flag': None,
#      'pm10Flag': None,
#      'o3Grade': '1',
#      'pm10Value': '75',
#      'khaiGrade': '2',
#      'pm25Value': '53',
#      'sidoName': '서울',
#      'no2Flag': None,
#      'no2Grade': '1',
# ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()['response']['body']['items']
print(type(data))
print(len(data))
print(data)
df = pd.DataFrame(data)
df['pm25Grade']
# Out:
# <class 'list'>
# 40
# ...

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_json('air_pollution.json',indent=4, force_ascii=False)

## EXCEL 형식 데이터 저장
df.to_excel('air_polltion.xlsx',index=False)
## HTML 형식 데이터 저장
df.to_html('air_polltion.html')
